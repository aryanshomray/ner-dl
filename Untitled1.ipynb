# %%
import pandas as pd

# %%
df=pd.read_csv('data/ner_dataset.csv',encoding = 'unicode_escape',header=None)

# %%
df[0].isnull().sum()
# Out:
# 1000616

# %%
df
# Out:
#                        0              1    2      3
# 0            Sentence: 1      Thousands  NNS      O
# 1                    NaN             of   IN      O
# 2                    NaN  demonstrators  NNS      O
# 3                    NaN           have  VBP      O
# 4                    NaN        marched  VBN      O
# 5                    NaN        through   IN      O
# 6                    NaN         London  NNP  B-geo
# 7                    NaN             to   TO      O
# 8                    NaN        protest   VB      O
# 9                    NaN            the   DT      O
# 10                   NaN            war   NN      O
# 11                   NaN             in   IN      O
# 12                   NaN           Iraq  NNP  B-geo
# 13                   NaN            and   CC      O
# 14                   NaN         demand   VB      O
# 15                   NaN            the   DT      O
# 16                   NaN     withdrawal   NN      O
# ...
